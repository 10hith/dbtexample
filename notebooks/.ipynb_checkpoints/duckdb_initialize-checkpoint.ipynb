# %%
import duckdb
import pandas as pd
# No need to import duckdb_engine
#  jupysql will auto-detect the driver needed based on the connection string!

# Import jupysql Jupyter extension to create SQL cells
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# Connect jupysql to DuckDB using a SQLAlchemy-style connection string
# %sql duckdb:///:memory:
# %sql duckdb:///path/to/file.db

# %%
# %sql duckdb:///:memory:
# %sql duckdb://mnt/c/wsl_transfers/crimeapp.db
# Out:
# connect(): incompatible function arguments. The following argument types are supported:
#     1. (database: str = ':memory:', read_only: bool = False, config: object = None) -> duckdb.DuckDBPyConnection
#
# Invoked with: kwargs: host='mnt', database='c/wsl_transfers/crimeapp.db'
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# initiate a duckdb databse
import pyarrow.dataset as ds
import duckdb
import polars as pl

con = duckdb.connect("/mnt/c/wsl_transfers/cens.db")
DATA_PATH='/home/basal/live_datasets'

# %%
arrow_df = con.execute("""
select * from pc_to_oa_mapping
""").arrow()
oa_mapping = pl.from_arrow(arrow_df)

# %%
oa_mapping.schema.keys()
# Out:
# dict_keys(['pcd', 'gridgb1e', 'gridgb1n', 'oa21cd', 'lsoa21cd', 'lsoa21nm', 'msoa21cd', 'msoa21nm', 'ltla22cd', 'ltla22nm', 'ltla22nmw', 'utla22cd', 'utla22nm', 'utla22nmw', 'rgn22cd', 'rgn22nm', 'rgn22nmw', 'ctry22cd', 'ctry22nm', 'ctry22nmw', 'nat22cd', 'nat22nm', 'nat22nmw'])

# %%
# Out:
# [<polars.internals.expr.expr.Expr at 0x7ff6f06d6e80>,
#  <polars.internals.expr.expr.Expr at 0x7ff6f06d65b0>,
#  <polars.internals.expr.expr.Expr at 0x7ff6f06d6a60>,
#  <polars.internals.expr.expr.Expr at 0x7ff6f06d6ac0>,
#  <polars.internals.expr.expr.Expr at 0x7ff6f06d66d0>,
#  <polars.internals.expr.expr.Expr at 0x7ff6f06d6bb0>,
#  <polars.internals.expr.expr.Expr at 0x7ff6f06d6b50>,
#  <polars.internals.expr.expr.Expr at 0x7ff6f06d6a90>,
#  <polars.internals.expr.expr.Expr at 0x7ff6f06d69a0>]

# %%
unique_counts = oa_mapping.select(
    [
        pl.col(col).unique().count().alias(f"{col}_unique_count") for col in oa_mapping.schema.keys() if 'cd' in col
    ]
)

# %%
unique_counts
# Out:
# shape: (1, 9)
# ┌────────────┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ pcd_unique ┆ oa21cd_uni ┆ lsoa21cd_u ┆ msoa21cd_u ┆ ... ┆ utla22cd_u ┆ rgn22cd_un ┆ ctry22cd_u ┆ nat22cd_un │
# │ _count     ┆ que_count  ┆ nique_coun ┆ nique_coun ┆     ┆ nique_coun ┆ ique_count ┆ nique_coun ┆ ique_count │
# │ ---        ┆ ---        ┆ t          ┆ t          ┆     ┆ t          ┆ ---        ┆ t          ┆ ---        │
# │ u32        ┆ u32        ┆ ---        ┆ ---        ┆     ┆ ---        ┆ u32        ┆ ---        ┆ u32        │
# │            ┆            ┆ u32        ┆ u32        ┆     ┆ u32        ┆            ┆ u32        ┆            │
# ╞════════════╪════════════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ 2352552    ┆ 188861     ┆ 35673      ┆ 7265       ┆ ... ┆ 175        ┆ 11         ┆ 3          ┆ 2          │
# └────────────┴────────────┴────────────┴────────────┴─────┴────────────┴────────────┴────────────┴────────────┘

# %%
import pyarrow as pa
my_arrow = pa.Table.from_pydict({'a':[42]})

# %%
# unique_counts.to_arrow()
con.execute("""
CREATE TABLE unique_area_counts AS select * from unique_counts
""")

# %%
# pdf = ts008.to_pandas()
# pdf

# %%
ts008 = pl.from_arrow(
    con.execute("""
        select * from ts008
    """).arrow()
)

# %%
ts008.schema
# Out:
# {'date': Int32,
#  'geography': Utf8,
#  'geography code': Utf8,
#  'Sex: All persons; measures: Value': Int32,
#  'Sex: Female; measures: Value': Int32,
#  'Sex: Male; measures: Value': Int32,
#  'filename': Utf8}

# %%
ts008\
.filter(pl.col("filename").str.contains('rgn'))\
.select([
    pl.col('geography'),
    pl.col('geography code')
])
# Out:
# shape: (10, 2)
# ┌──────────────────────────┬────────────────┐
# │ geography                ┆ geography code │
# │ ---                      ┆ ---            │
# │ str                      ┆ str            │
# ╞══════════════════════════╪════════════════╡
# │ North East               ┆ E12000001      │
# │ North West               ┆ E12000002      │
# │ Yorkshire and The Humber ┆ E12000003      │
# │ East Midlands            ┆ E12000004      │
# │ ...                      ┆ ...            │
# │ London                   ┆ E12000007      │
# │ South East               ┆ E12000008      │
# │ South West               ┆ E12000009      │
# │ Wales                    ┆ W92000004      │
# └──────────────────────────┴────────────────┘

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
ts008.select([
    pl.col('filename').unique().str.split('/')
])[:, -1]
# Out:
# shape: (8,)
# Series: 'filename' [list[str]]
# [
# 	["", "mnt", ... "census2021-ts008-lsoa.csv"]
# 	["", "mnt", ... "census2021-ts008-oa.csv"]
# 	["", "mnt", ... "census2021-ts008-ctry.csv"]
# 	["", "mnt", ... "census2021-ts008-msoa.csv"]
# 	["", "mnt", ... "census2021-ts008-ulta.csv"]
# 	["", "mnt", ... "census2021-ts008-ward.csv"]
# 	["", "mnt", ... "census2021-ts008-ltla.csv"]
# 	["", "mnt", ... "census2021-ts008-rgn.csv"]
# ]

# %%
import glob

# %%
# glob.glob("/mnt/c/wsl_transfers/cens_staging/cens_topic_summaries_parquet/*.parquet")[0].

# %%
files = glob.glob("/mnt/c/wsl_transfers/cens_staging/cens_topic_summaries_parquet/*.parquet")
con = duckdb.connect("/mnt/c/wsl_transfers/cens.db")

# %%
for file in files[:1]:
    table_name = os.path.basename(file).split('.')[0]
    pdf = con.execute(f"""
    create or replace table test_tbl as (
    with raw_tbl as (select * from read_parquet('{file}'))
    select
        case 
        when filename like '%-ctry.csv%' then 'ctry'
        when filename like '%-rgn.csv%' then 'rgn'
        when filename like '%-utla.csv%' then 'utla'
        when filename like '%-ltla.csv%' then 'lad'
        when filename like '%-ward.csv%' then 'ward'
        when filename like '%-msoa.csv%' then 'msoa'
        when filename like '%-msoa.csv%' then 'msoa'
        when filename like '%-lsoa.csv%' then 'lsoa'
        when filename like '%-oa.csv%' then 'oa'
        else 'na'
        end AS area_lvl,
        *
    from raw_tbl)
    """).df()
# Out:
#     Count
# 0  239972

# %%
pdf = con.execute("select * from test_tbl").df()

# %%
con.close()

# %%
pl_df[pl.col("area_nm")]
# Out:
# shape: (239972, 8)
# ┌──────────┬──────┬──────────────┬────────────┬────────────┬────────────┬────────────┬─────────────┐
# │ area_lvl ┆ date ┆ geography    ┆ geography  ┆ Residence  ┆ Residence  ┆ Residence  ┆ filename    │
# │ ---      ┆ ---  ┆ ---          ┆ code       ┆ type:      ┆ type:      ┆ type:      ┆ ---         │
# │ str      ┆ i32  ┆ str          ┆ ---        ┆ Total; mea ┆ Lives in a ┆ Lives in a ┆ str         │
# │          ┆      ┆              ┆ str        ┆ sures:...  ┆ house...   ┆ commu...   ┆             │
# │          ┆      ┆              ┆            ┆ ---        ┆ ---        ┆ ---        ┆             │
# │          ┆      ┆              ┆            ┆ i32        ┆ i32        ┆ i32        ┆             │
# ╞══════════╪══════╪══════════════╪════════════╪════════════╪════════════╪════════════╪═════════════╡
# │ ctry     ┆ 2021 ┆ England and  ┆ K04000001  ┆ 59597542   ┆ 58555851   ┆ 1041691    ┆ /mnt/c/stag │
# │          ┆      ┆ Wales        ┆            ┆            ┆            ┆            ┆ ing_unzippe │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ d/census20. │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ..          │
# │ ctry     ┆ 2021 ┆ England      ┆ E92000001  ┆ 56490048   ┆ 55504302   ┆ 985746     ┆ /mnt/c/stag │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ing_unzippe │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ d/census20. │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ..          │
# │ ctry     ┆ 2021 ┆ Wales        ┆ W92000004  ┆ 3107494    ┆ 3051549    ┆ 55945      ┆ /mnt/c/stag │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ing_unzippe │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ d/census20. │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ..          │
# │ lsoa     ┆ 2021 ┆ Hartlepool   ┆ E01011954  ┆ 2284       ┆ 2284       ┆ 0          ┆ /mnt/c/stag │
# │          ┆      ┆ 001A         ┆            ┆            ┆            ┆            ┆ ing_unzippe │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ d/census20. │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ..          │
# │ ...      ┆ ...  ┆ ...          ┆ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ...         │
# │ ward     ┆ 2021 ┆ St Kingsmark ┆ W05001797  ┆ 1968       ┆ 1909       ┆ 59         ┆ /mnt/c/stag │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ing_unzippe │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ d/census20. │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ..          │
# │ ward     ┆ 2021 ┆ Town (Monmou ┆ W05001798  ┆ 2014       ┆ 1914       ┆ 100        ┆ /mnt/c/stag │
# │          ┆      ┆ thshire)     ┆            ┆            ┆            ┆            ┆ ing_unzippe │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ d/census20. │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ..          │
# │ ward     ┆ 2021 ┆ West End (Mo ┆ W05001799  ┆ 1939       ┆ 1902       ┆ 37         ┆ /mnt/c/stag │
# │          ┆      ┆ nmouthshire) ┆            ┆            ┆            ┆            ┆ ing_unzippe │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ d/census20. │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ..          │
# │ ward     ┆ 2021 ┆ Wyesham      ┆ W05001800  ┆ 2125       ┆ 2118       ┆ 7          ┆ /mnt/c/stag │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ing_unzippe │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ d/census20. │
# │          ┆      ┆              ┆            ┆            ┆            ┆            ┆ ..          │
# └──────────┴──────┴──────────────┴────────────┴────────────┴────────────┴────────────┴─────────────┘

# %%
pdf.query("area_lvl=='na'")
# Out:
#        area_lvl  date       geography geography code  \
# 232160       na  2021      Darlington      E06000005
# 232161       na  2021   County Durham      E06000047
# 232162       na  2021      Hartlepool      E06000001
# 232163       na  2021   Middlesbrough      E06000002
# 232164       na  2021  Northumberland      E06000057
# ...         ...   ...             ...            ...
# 232329       na  2021      Caerphilly      W06000018
# 232330       na  2021   Blaenau Gwent      W06000019
# 232331       na  2021         Torfaen      W06000020
# 232332       na  2021   Monmouthshire      W06000021
# 232333       na  2021         Newport      W06000022
#
#         Residence type: Total; measures: Value  \
# 232160                                  107799
# 232161                                  522068
# 232162                                   92338
# 232163                                  143926
# 232164                                  320567
# ...                                        ...
# 232329                                  175952
# 232330                                   66904
# 232331                                   92276
# 232332                                   92957
# 232333                                  159592
#
#         Residence type: Lives in a household; measures: Value  \
# 232160                                             106818
# 232161                                             508762
# 232162                                              91471
# 232163                                             141421
# 232164                                             316102
# ...                                                   ...
# 232329                                             175055
# 232330                                              66552
# 232331                                              91725
# 232332                                              91515
# 232333                                             158205
#
#         Residence type: Lives in a communal establishment; measures: Value  \
# 232160                                                981
# 232161                                              13306
# 232162                                                867
# 232163                                               2505
# 232164                                               4465
# ...                                                   ...
# 232329                                                897
# 232330                                                352
# 232331                                                551
# 232332                                               1442
# 232333                                               1387
#
#                                                  filename
# 232160  /mnt/c/staging_unzipped/census2021-ts001-utla.csv
# 232161  /mnt/c/staging_unzipped/census2021-ts001-utla.csv
# 232162  /mnt/c/staging_unzipped/census2021-ts001-utla.csv
# 232163  /mnt/c/staging_unzipped/census2021-ts001-utla.csv
# 232164  /mnt/c/staging_unzipped/census2021-ts001-utla.csv
# ...                                                   ...
# 232329  /mnt/c/staging_unzipped/census2021-ts001-utla.csv
# 232330  /mnt/c/staging_unzipped/census2021-ts001-utla.csv
# 232331  /mnt/c/staging_unzipped/census2021-ts001-utla.csv
# 232332  /mnt/c/staging_unzipped/census2021-ts001-utla.csv
# 232333  /mnt/c/staging_unzipped/census2021-ts001-utla.csv
#
# [174 rows x 8 columns]
